# %%
from pulp import LpMaximize, LpMinimize, LpProblem, LpStatus, lpSum, LpVariable, LpBinary, LpSolutionIntegerFeasible
import pandas as pd
import numpy as np
import itertools

# %%
credits = {
    'Matemática Estructural': 3,
    'Calc. Dif': 3,
    'Física 1': 3,
    'IP':3,
    'Seminario de Matemáticas': 1,
    'Calc. Int': 3,
    'Algebra Lineal 1': 3,
    'EDA':3,
    'Física 2': 3,
    'Calc. Vec': 3,
    'Algebra Abstracta 1': 3,
    'Algebra Lineal 2': 3,
    'Electiva Básica 1': 3,
    'Electiva Básica 2': 3,
    'Análisis': 3,
    'Seminario de Transición': 2,
    'Var. Compleja': 3,
    'Ecuaciones Diferenciales': 3,
    'Probabilidad (Hon)': 3,
    'Algebra Abstracta 2': 3,
    'Lógica': 3,
    'Estadistica': 3,
    'Topologia': 3,
    'Geometría Diferencial': 3,
    'Medida': 3,
    'Analisis Numérico': 3,
    'Electiva Avanzada 1': 3,
    'Electiva Avanzada 2': 3,
    'Electiva Avanzada 3': 3,
    'Práctica de Enseñanza': 3,
    'Proyecto de Grado': 3,
    'Area Menor 1': 3,
    'Area Menor 2': 3,
    'CLE 1': 3,
    'CLE 2': 3,
    'CBU 1': 2,
    'CBU 2': 2,
    'CBU 3': 2,
    'CBU 4': 2,
    'CBU 5': 2,
    'CBCC': 2,
    'Escritura Universitaria 1': 2,
    'Escritura Universitaria 2': 2,
    'Constitución y Democracia': 3
}

max_credits = {1: 18, 2: 20, 3: 20, 4: 20, 5:20, 6: 20, 7: 20, 8: 20}

prereq = {
    'Calc. Int': ['Calc. Dif'],
    'EDA': ['IP'],
    'Algebra Lineal 1': ['Calc. Dif'],
    'Física 2': ['Física 1'],
    'Calc. Vec': ['Calc. Int', 'Algebra Lineal 1'],
    'Algebra Abstracta 1': ['Algebra Lineal 1', 'Matemática Estructural'],
    'Algebra Lineal 2': ['Algebra Lineal 1'],
    'Análisis': ['Calc. Int', 'Matemática Estructural'],
    'Seminario de Transición': ['Seminario de Matemáticas'],
    'Var. Compleja': ['Calc. Vec'],
    'Ecuaciones Diferenciales': ['Calc. Vec'],
    'Probabilidad (Hon)': ['Calc. Vec'],
    'Algebra Abstracta 2': ['Algebra Abstracta 1'],
    'Lógica': ['Algebra Abstracta 1'],
    'Estadistica': ['Probabilidad (Hon)'],
    'Topologia': ['Análisis'],
    'Geometría Diferencial': ['Análisis'],
    'Medida': ['Análisis'],
    'Analisis Numérico': ['Ecuaciones Diferenciales','IP'],
    'Práctica de Enseñanza': ['Algebra Abstracta 2'],
    'Proyecto de Grado': ['Seminario de Transición']
}

coreq = {
    'Física 1': ['Calc. Dif'],
    'Física 2': ['Calc. Int'],
    'Electiva Básica 1': ['Calc. Int'],
    'Electiva Básica 2': ['Calc. Int'],
    'Electiva Avanzada 1': ['Análisis'],
    'Electiva Avanzada 2': ['Análisis'],
    'Electiva Avanzada 3': ['Análisis'],
    'Escritura Universitaria 2': ['Escritura Universitaria 1'],
}

S = 8

# %%
variables = {}
i = 1
for m in credits:
    for j in range(0,S+1):
        variables[(m,j)] = LpVariable(name='x_'+str(i)+','+str(j), lowBound = 0, upBound= 1, cat=LpBinary)
    i += 1
variables
# Out:
# {('Matemática Estructural', 0): x_1,0,
#  ('Matemática Estructural', 1): x_1,1,
#  ('Matemática Estructural', 2): x_1,2,
#  ('Matemática Estructural', 3): x_1,3,
#  ('Matemática Estructural', 4): x_1,4,
#  ('Matemática Estructural', 5): x_1,5,
#  ('Matemática Estructural', 6): x_1,6,
#  ('Matemática Estructural', 7): x_1,7,
#  ('Matemática Estructural', 8): x_1,8,
#  ('Calc. Dif', 0): x_2,0,
#  ('Calc. Dif', 1): x_2,1,
#  ('Calc. Dif', 2): x_2,2,
#  ('Calc. Dif', 3): x_2,3,
#  ('Calc. Dif', 4): x_2,4,
#  ('Calc. Dif', 5): x_2,5,
#  ('Calc. Dif', 6): x_2,6,
#  ('Calc. Dif', 7): x_2,7,
#  ('Calc. Dif', 8): x_2,8,
#  ('Física 1', 0): x_3,0,
#  ('Física 1', 1): x_3,1,
#  ('Física 1', 2): x_3,2,
#  ('Física 1', 3): x_3,3,
#  ('Física 1', 4): x_3,4,
#  ('Física 1', 5): x_3,5,
#  ('Física 1', 6): x_3,6,
#  ('Física 1', 7): x_3,7,
#  ('Física 1', 8): x_3,8,
#  ('IP', 0): x_4,0,
#  ('IP', 1): x_4,1,
#  ('IP', 2): x_4,2,
#  ('IP', 3): x_4,3,
#  ('IP', 4): x_4,4,
#  ('IP', 5): x_4,5,
#  ('IP', 6): x_4,6,
#  ('IP', 7): x_4,7,
#  ('IP', 8): x_4,8,
#  ('Seminario de Matemáticas', 0): x_5,0,
#  ('Seminario de Matemáticas', 1): x_5,1,
#  ('Seminario de Matemáticas', 2): x_5,2,
#  ('Seminario de Matemáticas', 3): x_5,3,
#  ('Seminario de Matemáticas', 4): x_5,4,
#  ('Seminario de Matemáticas', 5): x_5,5,
#  ('Seminario de Matemáticas', 6): x_5,6,
#  ('Seminario de Matemáticas', 7): x_5,7,
#  ('Seminario de Matemáticas', 8): x_5,8,
#  ('Calc. Int', 0): x_6,0,
#  ('Calc. Int', 1): x_6,1,
#  ('Calc. Int', 2): x_6,2,
#  ('Calc. Int', 3): x_6,3,
#  ('Calc. Int', 4): x_6,4,
#  ('Calc. Int', 5): x_6,5,
#  ('Calc. Int', 6): x_6,6,
#  ('Calc. Int', 7): x_6,7,
#  ('Calc. Int', 8): x_6,8,
#  ('Algebra Lineal 1', 0): x_7,0,
#  ('Algebra Lineal 1', 1): x_7,1,
#  ('Algebra Lineal 1', 2): x_7,2,
#  ('Algebra Lineal 1', 3): x_7,3,
#  ('Algebra Lineal 1', 4): x_7,4,
#  ('Algebra Lineal 1', 5): x_7,5,
#  ('Algebra Lineal 1', 6): x_7,6,
#  ('Algebra Lineal 1', 7): x_7,7,
#  ('Algebra Lineal 1', 8): x_7,8,
#  ('EDA', 0): x_8,0,
#  ('EDA', 1): x_8,1,
#  ('EDA', 2): x_8,2,
#  ('EDA', 3): x_8,3,
#  ('EDA', 4): x_8,4,
#  ('EDA', 5): x_8,5,
#  ('EDA', 6): x_8,6,
#  ('EDA', 7): x_8,7,
#  ('EDA', 8): x_8,8,
#  ('Física 2', 0): x_9,0,
#  ('Física 2', 1): x_9,1,
#  ('Física 2', 2): x_9,2,
#  ('Física 2', 3): x_9,3,
#  ('Física 2', 4): x_9,4,
#  ('Física 2', 5): x_9,5,
#  ('Física 2', 6): x_9,6,
#  ('Física 2', 7): x_9,7,
#  ('Física 2', 8): x_9,8,
#  ('Calc. Vec', 0): x_10,0,
#  ('Calc. Vec', 1): x_10,1,
#  ('Calc. Vec', 2): x_10,2,
#  ('Calc. Vec', 3): x_10,3,
#  ('Calc. Vec', 4): x_10,4,
#  ('Calc. Vec', 5): x_10,5,
#  ('Calc. Vec', 6): x_10,6,
#  ('Calc. Vec', 7): x_10,7,
#  ('Calc. Vec', 8): x_10,8,
#  ('Algebra Abstracta 1', 0): x_11,0,
#  ('Algebra Abstracta 1', 1): x_11,1,
#  ('Algebra Abstracta 1', 2): x_11,2,
#  ('Algebra Abstracta 1', 3): x_11,3,
#  ('Algebra Abstracta 1', 4): x_11,4,
#  ('Algebra Abstracta 1', 5): x_11,5,
#  ('Algebra Abstracta 1', 6): x_11,6,
#  ('Algebra Abstracta 1', 7): x_11,7,
#  ('Algebra Abstracta 1', 8): x_11,8,
#  ('Algebra Lineal 2', 0): x_12,0,
#  ('Algebra Lineal 2', 1): x_12,1,
#  ('Algebra Lineal 2', 2): x_12,2,
#  ('Algebra Lineal 2', 3): x_12,3,
#  ('Algebra Lineal 2', 4): x_12,4,
#  ('Algebra Lineal 2', 5): x_12,5,
#  ('Algebra Lineal 2', 6): x_12,6,
#  ('Algebra Lineal 2', 7): x_12,7,
#  ('Algebra Lineal 2', 8): x_12,8,
#  ('Electiva Básica 1', 0): x_13,0,
#  ('Electiva Básica 1', 1): x_13,1,
#  ('Electiva Básica 1', 2): x_13,2,
#  ('Electiva Básica 1', 3): x_13,3,
#  ('Electiva Básica 1', 4): x_13,4,
#  ('Electiva Básica 1', 5): x_13,5,
#  ('Electiva Básica 1', 6): x_13,6,
#  ('Electiva Básica 1', 7): x_13,7,
#  ('Electiva Básica 1', 8): x_13,8,
#  ('Electiva Básica 2', 0): x_14,0,
#  ('Electiva Básica 2', 1): x_14,1,
#  ('Electiva Básica 2', 2): x_14,2,
#  ('Electiva Básica 2', 3): x_14,3,
#  ('Electiva Básica 2', 4): x_14,4,
#  ('Electiva Básica 2', 5): x_14,5,
#  ('Electiva Básica 2', 6): x_14,6,
#  ('Electiva Básica 2', 7): x_14,7,
#  ('Electiva Básica 2', 8): x_14,8,
#  ('Análisis', 0): x_15,0,
#  ('Análisis', 1): x_15,1,
#  ('Análisis', 2): x_15,2,
#  ('Análisis', 3): x_15,3,
#  ('Análisis', 4): x_15,4,
#  ('Análisis', 5): x_15,5,
#  ('Análisis', 6): x_15,6,
#  ('Análisis', 7): x_15,7,
#  ('Análisis', 8): x_15,8,
#  ('Seminario de Transición', 0): x_16,0,
#  ('Seminario de Transición', 1): x_16,1,
#  ('Seminario de Transición', 2): x_16,2,
#  ('Seminario de Transición', 3): x_16,3,
#  ('Seminario de Transición', 4): x_16,4,
#  ('Seminario de Transición', 5): x_16,5,
#  ('Seminario de Transición', 6): x_16,6,
#  ('Seminario de Transición', 7): x_16,7,
#  ('Seminario de Transición', 8): x_16,8,
#  ('Var. Compleja', 0): x_17,0,
#  ('Var. Compleja', 1): x_17,1,
#  ('Var. Compleja', 2): x_17,2,
#  ('Var. Compleja', 3): x_17,3,
#  ('Var. Compleja', 4): x_17,4,
#  ('Var. Compleja', 5): x_17,5,
#  ('Var. Compleja', 6): x_17,6,
#  ('Var. Compleja', 7): x_17,7,
#  ('Var. Compleja', 8): x_17,8,
#  ('Ecuaciones Diferenciales', 0): x_18,0,
#  ('Ecuaciones Diferenciales', 1): x_18,1,
#  ('Ecuaciones Diferenciales', 2): x_18,2,
#  ('Ecuaciones Diferenciales', 3): x_18,3,
#  ('Ecuaciones Diferenciales', 4): x_18,4,
#  ('Ecuaciones Diferenciales', 5): x_18,5,
#  ('Ecuaciones Diferenciales', 6): x_18,6,
#  ('Ecuaciones Diferenciales', 7): x_18,7,
#  ('Ecuaciones Diferenciales', 8): x_18,8,
#  ('Probabilidad (Hon)', 0): x_19,0,
#  ('Probabilidad (Hon)', 1): x_19,1,
#  ('Probabilidad (Hon)', 2): x_19,2,
#  ('Probabilidad (Hon)', 3): x_19,3,
#  ('Probabilidad (Hon)', 4): x_19,4,
#  ('Probabilidad (Hon)', 5): x_19,5,
#  ('Probabilidad (Hon)', 6): x_19,6,
#  ('Probabilidad (Hon)', 7): x_19,7,
#  ('Probabilidad (Hon)', 8): x_19,8,
#  ('Algebra Abstracta 2', 0): x_20,0,
#  ('Algebra Abstracta 2', 1): x_20,1,
#  ('Algebra Abstracta 2', 2): x_20,2,
#  ('Algebra Abstracta 2', 3): x_20,3,
#  ('Algebra Abstracta 2', 4): x_20,4,
#  ('Algebra Abstracta 2', 5): x_20,5,
#  ('Algebra Abstracta 2', 6): x_20,6,
#  ('Algebra Abstracta 2', 7): x_20,7,
#  ('Algebra Abstracta 2', 8): x_20,8,
#  ('Lógica', 0): x_21,0,
#  ('Lógica', 1): x_21,1,
#  ('Lógica', 2): x_21,2,
#  ('Lógica', 3): x_21,3,
#  ('Lógica', 4): x_21,4,
#  ('Lógica', 5): x_21,5,
#  ('Lógica', 6): x_21,6,
#  ('Lógica', 7): x_21,7,
#  ('Lógica', 8): x_21,8,
#  ('Estadistica', 0): x_22,0,
#  ('Estadistica', 1): x_22,1,
#  ('Estadistica', 2): x_22,2,
#  ('Estadistica', 3): x_22,3,
#  ('Estadistica', 4): x_22,4,
#  ('Estadistica', 5): x_22,5,
#  ('Estadistica', 6): x_22,6,
#  ('Estadistica', 7): x_22,7,
#  ('Estadistica', 8): x_22,8,
#  ('Topologia', 0): x_23,0,
#  ('Topologia', 1): x_23,1,
#  ('Topologia', 2): x_23,2,
#  ('Topologia', 3): x_23,3,
#  ('Topologia', 4): x_23,4,
#  ('Topologia', 5): x_23,5,
#  ('Topologia', 6): x_23,6,
#  ('Topologia', 7): x_23,7,
#  ('Topologia', 8): x_23,8,
#  ('Geometría Diferencial', 0): x_24,0,
#  ('Geometría Diferencial', 1): x_24,1,
#  ('Geometría Diferencial', 2): x_24,2,
#  ('Geometría Diferencial', 3): x_24,3,
#  ('Geometría Diferencial', 4): x_24,4,
#  ('Geometría Diferencial', 5): x_24,5,
#  ('Geometría Diferencial', 6): x_24,6,
#  ('Geometría Diferencial', 7): x_24,7,
#  ('Geometría Diferencial', 8): x_24,8,
#  ('Medida', 0): x_25,0,
#  ('Medida', 1): x_25,1,
#  ('Medida', 2): x_25,2,
#  ('Medida', 3): x_25,3,
#  ('Medida', 4): x_25,4,
#  ('Medida', 5): x_25,5,
#  ('Medida', 6): x_25,6,
#  ('Medida', 7): x_25,7,
#  ('Medida', 8): x_25,8,
#  ('Analisis Numérico', 0): x_26,0,
#  ('Analisis Numérico', 1): x_26,1,
#  ('Analisis Numérico', 2): x_26,2,
#  ('Analisis Numérico', 3): x_26,3,
#  ('Analisis Numérico', 4): x_26,4,
#  ('Analisis Numérico', 5): x_26,5,
#  ('Analisis Numérico', 6): x_26,6,
#  ('Analisis Numérico', 7): x_26,7,
#  ('Analisis Numérico', 8): x_26,8,
#  ('Electiva Avanzada 1', 0): x_27,0,
#  ('Electiva Avanzada 1', 1): x_27,1,
#  ('Electiva Avanzada 1', 2): x_27,2,
#  ('Electiva Avanzada 1', 3): x_27,3,
#  ('Electiva Avanzada 1', 4): x_27,4,
#  ('Electiva Avanzada 1', 5): x_27,5,
#  ('Electiva Avanzada 1', 6): x_27,6,
#  ('Electiva Avanzada 1', 7): x_27,7,
#  ('Electiva Avanzada 1', 8): x_27,8,
#  ('Electiva Avanzada 2', 0): x_28,0,
#  ('Electiva Avanzada 2', 1): x_28,1,
#  ('Electiva Avanzada 2', 2): x_28,2,
#  ('Electiva Avanzada 2', 3): x_28,3,
#  ('Electiva Avanzada 2', 4): x_28,4,
#  ('Electiva Avanzada 2', 5): x_28,5,
#  ('Electiva Avanzada 2', 6): x_28,6,
#  ('Electiva Avanzada 2', 7): x_28,7,
#  ('Electiva Avanzada 2', 8): x_28,8,
#  ('Electiva Avanzada 3', 0): x_29,0,
#  ('Electiva Avanzada 3', 1): x_29,1,
#  ('Electiva Avanzada 3', 2): x_29,2,
#  ('Electiva Avanzada 3', 3): x_29,3,
#  ('Electiva Avanzada 3', 4): x_29,4,
#  ('Electiva Avanzada 3', 5): x_29,5,
#  ('Electiva Avanzada 3', 6): x_29,6,
#  ('Electiva Avanzada 3', 7): x_29,7,
#  ('Electiva Avanzada 3', 8): x_29,8,
#  ('Práctica de Enseñanza', 0): x_30,0,
#  ('Práctica de Enseñanza', 1): x_30,1,
#  ('Práctica de Enseñanza', 2): x_30,2,
#  ('Práctica de Enseñanza', 3): x_30,3,
#  ('Práctica de Enseñanza', 4): x_30,4,
#  ('Práctica de Enseñanza', 5): x_30,5,
#  ('Práctica de Enseñanza', 6): x_30,6,
#  ('Práctica de Enseñanza', 7): x_30,7,
#  ('Práctica de Enseñanza', 8): x_30,8,
#  ('Proyecto de Grado', 0): x_31,0,
#  ('Proyecto de Grado', 1): x_31,1,
#  ('Proyecto de Grado', 2): x_31,2,
#  ('Proyecto de Grado', 3): x_31,3,
#  ('Proyecto de Grado', 4): x_31,4,
#  ('Proyecto de Grado', 5): x_31,5,
#  ('Proyecto de Grado', 6): x_31,6,
#  ('Proyecto de Grado', 7): x_31,7,
#  ('Proyecto de Grado', 8): x_31,8,
#  ('Area Menor 1', 0): x_32,0,
#  ('Area Menor 1', 1): x_32,1,
#  ('Area Menor 1', 2): x_32,2,
#  ('Area Menor 1', 3): x_32,3,
#  ('Area Menor 1', 4): x_32,4,
#  ('Area Menor 1', 5): x_32,5,
#  ('Area Menor 1', 6): x_32,6,
#  ('Area Menor 1', 7): x_32,7,
#  ('Area Menor 1', 8): x_32,8,
#  ('Area Menor 2', 0): x_33,0,
#  ('Area Menor 2', 1): x_33,1,
#  ('Area Menor 2', 2): x_33,2,
#  ('Area Menor 2', 3): x_33,3,
#  ('Area Menor 2', 4): x_33,4,
#  ('Area Menor 2', 5): x_33,5,
#  ('Area Menor 2', 6): x_33,6,
#  ('Area Menor 2', 7): x_33,7,
#  ('Area Menor 2', 8): x_33,8,
#  ('CLE 1', 0): x_34,0,
#  ('CLE 1', 1): x_34,1,
#  ('CLE 1', 2): x_34,2,
#  ('CLE 1', 3): x_34,3,
#  ('CLE 1', 4): x_34,4,
#  ('CLE 1', 5): x_34,5,
#  ('CLE 1', 6): x_34,6,
#  ('CLE 1', 7): x_34,7,
#  ('CLE 1', 8): x_34,8,
#  ('CLE 2', 0): x_35,0,
#  ('CLE 2', 1): x_35,1,
#  ('CLE 2', 2): x_35,2,
#  ('CLE 2', 3): x_35,3,
#  ('CLE 2', 4): x_35,4,
#  ('CLE 2', 5): x_35,5,
#  ('CLE 2', 6): x_35,6,
#  ('CLE 2', 7): x_35,7,
#  ('CLE 2', 8): x_35,8,
#  ('CBU 1', 0): x_36,0,
#  ('CBU 1', 1): x_36,1,
#  ('CBU 1', 2): x_36,2,
#  ('CBU 1', 3): x_36,3,
#  ('CBU 1', 4): x_36,4,
#  ('CBU 1', 5): x_36,5,
#  ('CBU 1', 6): x_36,6,
#  ('CBU 1', 7): x_36,7,
#  ('CBU 1', 8): x_36,8,
#  ('CBU 2', 0): x_37,0,
#  ('CBU 2', 1): x_37,1,
#  ('CBU 2', 2): x_37,2,
#  ('CBU 2', 3): x_37,3,
#  ('CBU 2', 4): x_37,4,
#  ('CBU 2', 5): x_37,5,
#  ('CBU 2', 6): x_37,6,
#  ('CBU 2', 7): x_37,7,
#  ('CBU 2', 8): x_37,8,
#  ('CBU 3', 0): x_38,0,
#  ('CBU 3', 1): x_38,1,
#  ('CBU 3', 2): x_38,2,
#  ('CBU 3', 3): x_38,3,
#  ('CBU 3', 4): x_38,4,
#  ('CBU 3', 5): x_38,5,
#  ('CBU 3', 6): x_38,6,
#  ('CBU 3', 7): x_38,7,
#  ('CBU 3', 8): x_38,8,
#  ('CBU 4', 0): x_39,0,
#  ('CBU 4', 1): x_39,1,
#  ('CBU 4', 2): x_39,2,
#  ('CBU 4', 3): x_39,3,
#  ('CBU 4', 4): x_39,4,
#  ('CBU 4', 5): x_39,5,
#  ('CBU 4', 6): x_39,6,
#  ('CBU 4', 7): x_39,7,
#  ('CBU 4', 8): x_39,8,
#  ('CBU 5', 0): x_40,0,
#  ('CBU 5', 1): x_40,1,
#  ('CBU 5', 2): x_40,2,
#  ('CBU 5', 3): x_40,3,
#  ('CBU 5', 4): x_40,4,
#  ('CBU 5', 5): x_40,5,
#  ('CBU 5', 6): x_40,6,
#  ('CBU 5', 7): x_40,7,
#  ('CBU 5', 8): x_40,8,
#  ('CBCC', 0): x_41,0,
#  ('CBCC', 1): x_41,1,
#  ('CBCC', 2): x_41,2,
#  ('CBCC', 3): x_41,3,
#  ('CBCC', 4): x_41,4,
#  ('CBCC', 5): x_41,5,
#  ('CBCC', 6): x_41,6,
#  ('CBCC', 7): x_41,7,
#  ('CBCC', 8): x_41,8,
#  ('Escritura Universitaria 1', 0): x_42,0,
#  ('Escritura Universitaria 1', 1): x_42,1,
#  ('Escritura Universitaria 1', 2): x_42,2,
#  ('Escritura Universitaria 1', 3): x_42,3,
#  ('Escritura Universitaria 1', 4): x_42,4,
#  ('Escritura Universitaria 1', 5): x_42,5,
#  ('Escritura Universitaria 1', 6): x_42,6,
#  ('Escritura Universitaria 1', 7): x_42,7,
#  ('Escritura Universitaria 1', 8): x_42,8,
#  ('Escritura Universitaria 2', 0): x_43,0,
#  ('Escritura Universitaria 2', 1): x_43,1,
#  ('Escritura Universitaria 2', 2): x_43,2,
#  ('Escritura Universitaria 2', 3): x_43,3,
#  ('Escritura Universitaria 2', 4): x_43,4,
#  ('Escritura Universitaria 2', 5): x_43,5,
#  ('Escritura Universitaria 2', 6): x_43,6,
#  ('Escritura Universitaria 2', 7): x_43,7,
#  ('Escritura Universitaria 2', 8): x_43,8,
#  ('Constitución y Democracia', 0): x_44,0,
#  ('Constitución y Democracia', 1): x_44,1,
#  ('Constitución y Democracia', 2): x_44,2,
#  ('Constitución y Democracia', 3): x_44,3,
#  ('Constitución y Democracia', 4): x_44,4,
#  ('Constitución y Democracia', 5): x_44,5,
#  ('Constitución y Democracia', 6): x_44,6,
#  ('Constitución y Democracia', 7): x_44,7,
#  ('Constitución y Democracia', 8): x_44,8}

# %%
def create_model(credits,variables, max_credits,prereq,coreq,S):
    model = LpProblem('Horario')

    # Consistency of x-es along periods
    for m in credits:
        for j in range(0,S):
            model += ( variables[(m,j)] <= variables[(m,j+1)] )

    # Zero Semester 

    for m in credits:
        model += (variables[(m,0)] == 0)

    # First Semester

    sum = lpSum([variables[(m,1)] * credits[m] for m in credits])
    model += (sum <= max_credits[1])

    # Other Semesters

    for k in range(1,S):
        sum = lpSum([(variables[(m,k+1)] - variables[(m,k)]) * credits[m] for m in credits])
        model += (sum <= max_credits[k+1])

    # Pre-requisites

    for b in prereq:
        for a in prereq[b]:
            for j in range(0,S):
                model += (variables[(a,j)] >= variables[(b,j+1)])

    # Co-requisites

    for b in coreq:
        for a in coreq[b]:
            for j in range(1,S+1):
                model += (variables[(a,j)] >= variables[(b,j)])

    # Final condition

    for m in credits:
        model += (variables[(m,S)] == 1)
    return model

# %%
def reduce_max_credits(max_credits, n):
    upper_bound = max(list(max_credits.values())) - n
    return {j: min(upper_bound,k) for j,k in max_credits.items()}

# %%
bandera = True
n = 0
while bandera:
    model = create_model(credits, variables, reduce_max_credits(max_credits, n), prereq, coreq, S)
    status = model.solve()
    if status == 1:
        best_model = model
    else:
        bandera = False
    n += 1
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/9d2835a937c540599d9518952724d402-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/9d2835a937c540599d9518952724d402-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0002I 44 variables fixed
# Cgl0004I processed model has 306 rows, 223 columns (223 integer (223 of which binary)) and 1042 elements
# Cbc0045I No integer variables out of 223 objects (223 integer) have costs
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 14 integers unsatisfied sum - 4
# Cbc0038I Pass   1: suminf.    0.66667 (2) obj. 0 iterations 28
# Cbc0038I Pass   2: suminf.    0.66667 (2) obj. 0 iterations 14
# Cbc0038I Pass   3: suminf.    0.66667 (2) obj. 0 iterations 5
# Cbc0038I Pass   4: suminf.    0.66667 (2) obj. 0 iterations 15
# Cbc0038I Pass   5: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass   6: suminf.    1.33333 (4) obj. 0 iterations 84
# Cbc0038I Pass   7: suminf.    0.33333 (1) obj. 0 iterations 51
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 180 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 0 - took 0.00 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/273f86abf649442cb3f4e378b7d50be1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/273f86abf649442cb3f4e378b7d50be1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0002I 44 variables fixed
# Cgl0004I processed model has 306 rows, 223 columns (223 integer (223 of which binary)) and 1042 elements
# Cbc0045I No integer variables out of 223 objects (223 integer) have costs
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 8 integers unsatisfied sum - 2.66667
# Cbc0038I Pass   1: suminf.    1.00000 (3) obj. 0 iterations 8
# Cbc0038I Pass   2: suminf.    0.66667 (2) obj. 0 iterations 2
# Cbc0038I Pass   3: suminf.    1.00000 (3) obj. 0 iterations 4
# Cbc0038I Pass   4: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass   5: suminf.    2.77778 (11) obj. 0 iterations 92
# Cbc0038I Pass   6: suminf.    0.33333 (1) obj. 0 iterations 45
# Cbc0038I Pass   7: suminf.    0.33333 (1) obj. 0 iterations 2
# Cbc0038I Pass   8: suminf.    0.33333 (1) obj. 0 iterations 3
# Cbc0038I Pass   9: suminf.    0.33333 (1) obj. 0 iterations 2
# Cbc0038I Pass  10: suminf.    2.00000 (6) obj. 0 iterations 50
# Cbc0038I Pass  11: suminf.    0.33333 (1) obj. 0 iterations 37
# Cbc0038I Pass  12: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Pass  13: suminf.    0.33333 (1) obj. 0 iterations 4
# Cbc0038I Pass  14: suminf.    0.66667 (2) obj. 0 iterations 55
# Cbc0038I Pass  15: suminf.    0.66667 (2) obj. 0 iterations 21
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 152 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 0 - took 0.01 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/c7dbbf15a5f446f49f512e3dc4f6d7b0-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/c7dbbf15a5f446f49f512e3dc4f6d7b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0002I 44 variables fixed
# Cgl0004I processed model has 306 rows, 223 columns (223 integer (223 of which binary)) and 1042 elements
# Cbc0045I No integer variables out of 223 objects (223 integer) have costs
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 5 integers unsatisfied sum - 1.66667
# Cbc0038I Pass   1: suminf.    1.66667 (5) obj. 0 iterations 16
# Cbc0038I Pass   2: suminf.    0.33333 (1) obj. 0 iterations 18
# Cbc0038I Pass   3: suminf.    0.33333 (1) obj. 0 iterations 6
# Cbc0038I Pass   4: suminf.    4.66667 (14) obj. 0 iterations 80
# Cbc0038I Pass   5: suminf.    1.00000 (3) obj. 0 iterations 46
# Cbc0038I Pass   6: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 186 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 0 - took 0.00 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/f2828224ba0948689bb00331359e7e72-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/f2828224ba0948689bb00331359e7e72-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0002I 44 variables fixed
# Cgl0004I processed model has 306 rows, 223 columns (223 integer (223 of which binary)) and 1042 elements
# Cbc0045I No integer variables out of 223 objects (223 integer) have costs
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 10 integers unsatisfied sum - 1.88889
# Cbc0038I Pass   1: suminf.    1.00000 (3) obj. 0 iterations 9
# Cbc0038I Pass   2: suminf.    1.00000 (3) obj. 0 iterations 9
# Cbc0038I Pass   3: suminf.    1.00000 (3) obj. 0 iterations 13
# Cbc0038I Pass   4: suminf.    0.66667 (2) obj. 0 iterations 14
# Cbc0038I Pass   5: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass   6: suminf.    1.66667 (5) obj. 0 iterations 77
# Cbc0038I Pass   7: suminf.    1.00000 (3) obj. 0 iterations 37
# Cbc0038I Pass   8: suminf.    0.66667 (2) obj. 0 iterations 15
# Cbc0038I Pass   9: suminf.    0.33333 (1) obj. 0 iterations 6
# Cbc0038I Pass  10: suminf.    0.33333 (1) obj. 0 iterations 2
# Cbc0038I Pass  11: suminf.    1.66667 (5) obj. 0 iterations 60
# Cbc0038I Pass  12: suminf.    0.66667 (2) obj. 0 iterations 35
# Cbc0038I Pass  13: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Pass  14: suminf.    0.33333 (1) obj. 0 iterations 3
# Cbc0038I Pass  15: suminf.    2.00000 (6) obj. 0 iterations 59
# Cbc0038I Pass  16: suminf.    1.00000 (3) obj. 0 iterations 25
# Cbc0038I Pass  17: suminf.    0.66667 (2) obj. 0 iterations 10
# Cbc0038I Pass  18: suminf.    0.66667 (2) obj. 0 iterations 3
# Cbc0038I Pass  19: suminf.    2.33333 (5) obj. 0 iterations 63
# Cbc0038I Pass  20: suminf.    1.00000 (3) obj. 0 iterations 39
# Cbc0038I Pass  21: suminf.    0.66667 (2) obj. 0 iterations 5
# Cbc0038I Pass  22: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  23: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass  24: suminf.    1.00000 (3) obj. 0 iterations 75
# Cbc0038I Pass  25: suminf.    1.00000 (3) obj. 0 iterations 41
# Cbc0038I Pass  26: suminf.    0.33333 (1) obj. 0 iterations 12
# Cbc0038I Pass  27: suminf.    0.33333 (1) obj. 0 iterations 4
# Cbc0038I Pass  28: suminf.    2.00000 (5) obj. 0 iterations 50
# Cbc0038I Pass  29: suminf.    0.33333 (1) obj. 0 iterations 19
# Cbc0038I Pass  30: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Pass  31: suminf.    0.33333 (1) obj. 0 iterations 6
# Cbc0038I Pass  32: suminf.    0.33333 (1) obj. 0 iterations 9
# Cbc0038I Pass  33: suminf.    0.33333 (1) obj. 0 iterations 6
# Cbc0038I Pass  34: suminf.    2.00000 (6) obj. 0 iterations 59
# Cbc0038I Pass  35: suminf.    1.00000 (3) obj. 0 iterations 28
# Cbc0038I Pass  36: suminf.    0.33333 (1) obj. 0 iterations 7
# Cbc0038I Pass  37: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Pass  38: suminf.    1.66667 (4) obj. 0 iterations 55
# Cbc0038I Pass  39: suminf.    0.66667 (2) obj. 0 iterations 40
# Cbc0038I Pass  40: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  41: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass  42: suminf.    1.33333 (4) obj. 0 iterations 69
# Cbc0038I Pass  43: suminf.    0.66667 (2) obj. 0 iterations 36
# Cbc0038I Pass  44: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  45: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  46: suminf.    0.66667 (2) obj. 0 iterations 5
# Cbc0038I Pass  47: suminf.    2.00000 (5) obj. 0 iterations 73
# Cbc0038I Pass  48: suminf.    1.00000 (3) obj. 0 iterations 25
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 101 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 0 - took 0.02 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/921ba1d96bbe4bbd997e8aac03aa8829-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/921ba1d96bbe4bbd997e8aac03aa8829-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0002I 44 variables fixed
# Cgl0004I processed model has 306 rows, 223 columns (223 integer (223 of which binary)) and 1042 elements
# Cbc0045I No integer variables out of 223 objects (223 integer) have costs
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 9 integers unsatisfied sum - 3
# Cbc0038I Pass   1: suminf.    1.00000 (3) obj. 0 iterations 11
# Cbc0038I Pass   2: suminf.    1.00000 (3) obj. 0 iterations 12
# Cbc0038I Pass   3: suminf.    1.00000 (3) obj. 0 iterations 9
# Cbc0038I Pass   4: suminf.    0.66667 (2) obj. 0 iterations 68
# Cbc0038I Pass   5: suminf.    0.66667 (2) obj. 0 iterations 29
# Cbc0038I Pass   6: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass   7: suminf.    3.66667 (11) obj. 0 iterations 61
# Cbc0038I Pass   8: suminf.    2.00000 (6) obj. 0 iterations 36
# Cbc0038I Pass   9: suminf.    2.00000 (6) obj. 0 iterations 9
# Cbc0038I Pass  10: suminf.    1.33333 (4) obj. 0 iterations 12
# Cbc0038I Pass  11: suminf.    0.66667 (2) obj. 0 iterations 2
# Cbc0038I Pass  12: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  13: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  14: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  15: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  16: suminf.    4.33333 (13) obj. 0 iterations 79
# Cbc0038I Pass  17: suminf.    1.33333 (4) obj. 0 iterations 66
# Cbc0038I Pass  18: suminf.    1.33333 (4) obj. 0 iterations 5
# Cbc0038I Pass  19: suminf.    1.00000 (3) obj. 0 iterations 14
# Cbc0038I Pass  20: suminf.    0.66667 (2) obj. 0 iterations 3
# Cbc0038I Pass  21: suminf.    0.66667 (2) obj. 0 iterations 5
# Cbc0038I Pass  22: suminf.    0.66667 (2) obj. 0 iterations 1
# Cbc0038I Pass  23: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass  24: suminf.    3.33333 (9) obj. 0 iterations 86
# Cbc0038I Pass  25: suminf.    1.33333 (4) obj. 0 iterations 43
# Cbc0038I Pass  26: suminf.    1.33333 (4) obj. 0 iterations 1
# Cbc0038I Pass  27: suminf.    1.33333 (4) obj. 0 iterations 22
# Cbc0038I Pass  28: suminf.    1.33333 (4) obj. 0 iterations 7
# Cbc0038I Pass  29: suminf.    6.00000 (18) obj. 0 iterations 68
# Cbc0038I Pass  30: suminf.    0.33333 (1) obj. 0 iterations 52
# Cbc0038I Pass  31: suminf.    0.33333 (1) obj. 0 iterations 5
# Cbc0038I Pass  32: suminf.    0.33333 (1) obj. 0 iterations 4
# Cbc0038I Pass  33: suminf.    2.00000 (6) obj. 0 iterations 56
# Cbc0038I Pass  34: suminf.    0.66667 (2) obj. 0 iterations 24
# Cbc0038I Pass  35: suminf.    0.33333 (1) obj. 0 iterations 6
# Cbc0038I Pass  36: suminf.    0.33333 (1) obj. 0 iterations 2
# Cbc0038I Pass  37: suminf.    5.83333 (13) obj. 0 iterations 45
# Cbc0038I Pass  38: suminf.    1.66667 (5) obj. 0 iterations 38
# Cbc0038I Pass  39: suminf.    0.66667 (2) obj. 0 iterations 2
# Cbc0038I Pass  40: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass  41: suminf.    1.00000 (3) obj. 0 iterations 66
# Cbc0038I Pass  42: suminf.    0.66667 (2) obj. 0 iterations 31
# Cbc0038I Pass  43: suminf.    0.66667 (2) obj. 0 iterations 18
# Cbc0038I Pass  44: suminf.    0.66667 (2) obj. 0 iterations 3
# Cbc0038I Pass  45: suminf.    4.66667 (12) obj. 0 iterations 59
# Cbc0038I Pass  46: suminf.    1.33333 (4) obj. 0 iterations 33
# Cbc0038I Pass  47: suminf.    1.33333 (4) obj. 0 iterations 18
# Cbc0038I Pass  48: suminf.    1.00000 (3) obj. 0 iterations 15
# Cbc0038I Pass  49: suminf.    1.00000 (3) obj. 0 iterations 2
# Cbc0038I Pass  50: suminf.    1.00000 (3) obj. 0 iterations 13
# Cbc0038I Pass  51: suminf.    1.00000 (3) obj. 0 iterations 9
# Cbc0038I Pass  52: suminf.    1.00000 (3) obj. 0 iterations 14
# Cbc0038I Pass  53: suminf.    1.00000 (3) obj. 0 iterations 2
# Cbc0038I Pass  54: suminf.    3.33333 (10) obj. 0 iterations 59
# Cbc0038I Pass  55: suminf.    1.33333 (4) obj. 0 iterations 29
# Cbc0038I Pass  56: suminf.    1.33333 (4) obj. 0 iterations 7
# Cbc0038I Pass  57: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  58: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  59: suminf.    0.33333 (1) obj. 0 iterations 4
# Cbc0038I Pass  60: suminf.    0.33333 (1) obj. 0 iterations 2
# Cbc0038I Pass  61: suminf.    0.33333 (1) obj. 0 iterations 1
# Cbc0038I Pass  62: suminf.    2.00000 (6) obj. 0 iterations 44
# Cbc0038I Pass  63: suminf.    1.00000 (3) obj. 0 iterations 36
# Cbc0038I Pass  64: suminf.    0.66667 (2) obj. 0 iterations 13
# Cbc0038I Pass  65: suminf.    0.66667 (2) obj. 0 iterations 4
# Cbc0038I Pass  66: suminf.    0.66667 (2) obj. 0 iterations 2
# Cbc0038I Pass  67: suminf.    3.33333 (12) obj. 0 iterations 94
# Cbc0038I Pass  68: suminf.    1.00000 (3) obj. 0 iterations 60
# Cbc0038I Pass  69: suminf.    1.00000 (3) obj. 0 iterations 11
# Cbc0038I Pass  70: suminf.    1.00000 (3) obj. 0 iterations 11
# Cbc0038I Pass  71: suminf.    1.33333 (4) obj. 0 iterations 6
# Cbc0038I Pass  72: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  73: suminf.    1.00000 (3) obj. 0 iterations 6
# Cbc0038I Pass  74: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass  75: suminf.    1.00000 (3) obj. 0 iterations 13
# Cbc0038I Pass  76: suminf.    1.00000 (3) obj. 0 iterations 3
# Cbc0038I Pass  77: suminf.    1.33333 (4) obj. 0 iterations 10
# Cbc0038I Pass  78: suminf.    0.66667 (2) obj. 0 iterations 8
# Cbc0038I Pass  79: suminf.    1.00000 (3) obj. 0 iterations 6
# Cbc0038I Pass  80: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass  81: suminf.    1.00000 (3) obj. 0 iterations 13
# Cbc0038I Pass  82: suminf.    1.00000 (3) obj. 0 iterations 3
# Cbc0038I Pass  83: suminf.    1.33333 (4) obj. 0 iterations 8
# Cbc0038I Pass  84: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  85: suminf.    1.00000 (3) obj. 0 iterations 6
# Cbc0038I Pass  86: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass  87: suminf.    1.00000 (3) obj. 0 iterations 12
# Cbc0038I Pass  88: suminf.    1.00000 (3) obj. 0 iterations 3
# Cbc0038I Pass  89: suminf.    1.33333 (4) obj. 0 iterations 12
# Cbc0038I Pass  90: suminf.    0.66667 (2) obj. 0 iterations 7
# Cbc0038I Pass  91: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass  92: suminf.    1.00000 (3) obj. 0 iterations 3
# Cbc0038I Pass  93: suminf.    1.00000 (3) obj. 0 iterations 10
# Cbc0038I Pass  94: suminf.    1.00000 (3) obj. 0 iterations 3
# Cbc0038I Pass  95: suminf.    1.33333 (4) obj. 0 iterations 8
# Cbc0038I Pass  96: suminf.    0.66667 (2) obj. 0 iterations 6
# Cbc0038I Pass  97: suminf.    1.00000 (3) obj. 0 iterations 6
# Cbc0038I Pass  98: suminf.    1.00000 (3) obj. 0 iterations 5
# Cbc0038I Pass  99: suminf.    1.00000 (3) obj. 0 iterations 12
# Cbc0038I Pass 100: suminf.    2.66667 (9) obj. 0 iterations 80
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 60 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 306 rows 223 columns, reduced to 177 rows 162 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Full problem 307 rows 223 columns, reduced to 307 rows 223 columns - too large
# Cbc0038I After 0.05 seconds - Feasibility pump exiting - took 0.04 seconds
# Cbc0012I Integer solution of 0 found by DiveCoefficient after 2194 iterations and 0 nodes (0.83 seconds)
# Cbc0031I 12 added rows had average density of 146.16667
# Cbc0013I At root node, 12 cuts changed objective from 0 to 0 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 788 row cuts average 215.1 elements, 0 column cuts (0 active)  in 0.039 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 18 row cuts average 28.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 121 row cuts average 64.6 elements, 0 column cuts (0 active)  in 0.057 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 73 row cuts average 92.7 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 162 row cuts average 67.2 elements, 0 column cuts (0 active)  in 0.351 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0, took 2194 iterations and 0 nodes (0.83 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# Gomory was tried 100 times and created 788 cuts of which 0 were active after adding rounds of cuts (0.039 seconds)
# Knapsack was tried 100 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 121 cuts of which 0 were active after adding rounds of cuts (0.057 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 100 times and created 73 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# ZeroHalf was tried 100 times and created 162 cuts of which 0 were active after adding rounds of cuts (0.351 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               2194
# Time (CPU seconds):             0.80
# Time (Wallclock seconds):       0.84
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.80   (Wallclock seconds):       0.84
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/2a20849426734bb29bff7b6cd34488ea-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/8_/_cvslyx53dx_h_h6mjxq933m0000gn/T/2a20849426734bb29bff7b6cd34488ea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 717 COLUMNS
# At line 3491 RHS
# At line 4204 BOUNDS
# At line 4602 ENDATA
# Problem MODEL has 712 rows, 397 columns and 1980 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01

# %%
inv_var = {v.name: k for k, v in variables.items()}

periods = {}
for var in best_model.variables():
        if var.name in inv_var:
                m, j = inv_var[var.name]
                if var.value() == 1:
                        periods[m] = min(periods.get(m,S), j)

for j in range(1,S+1):
    print(f"{j} semestre:")
    for m in periods:
        if periods[m] == j:
            print('    ',m)
# Out:
# 1 semestre:
#      Matemática Estructural
#      Calc. Dif
#      Física 1
#      Area Menor 1
#      IP
# 2 semestre:
#      Electiva Básica 1
#      Electiva Básica 2
#      Area Menor 2
#      Calc. Int
#      Algebra Lineal 1
# 3 semestre:
#      Calc. Vec
#      Algebra Abstracta 1
#      Algebra Lineal 2
#      Análisis
#      Electiva Avanzada 1
# 4 semestre:
#      Var. Compleja
#      Ecuaciones Diferenciales
#      Probabilidad (Hon)
#      Algebra Abstracta 2
#      Lógica
# 5 semestre:
#      Topologia
#      CLE 1
#      CLE 2
#      Constitución y Democracia
#      EDA
# 6 semestre:
#      Estadistica
#      Geometría Diferencial
#      Medida
#      Analisis Numérico
#      Seminario de Matemáticas
# 7 semestre:
#      Seminario de Transición
#      Electiva Avanzada 2
#      Electiva Avanzada 3
#      Práctica de Enseñanza
#      CBU 1
#      CBU 2
#      Física 2
# 8 semestre:
#      Proyecto de Grado
#      CBU 3
#      CBU 4
#      CBU 5
#      CBCC
#      Escritura Universitaria 1
#      Escritura Universitaria 2
